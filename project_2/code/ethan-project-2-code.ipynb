# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Problem-Statement" data-toc-modified-id="Problem-Statement-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Problem Statement</a></span></li><li><span><a href="#Import-Libraries" data-toc-modified-id="Import-Libraries-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Import Libraries</a></span></li><li><span><a href="#Import-Data-and-Overview" data-toc-modified-id="Import-Data-and-Overview-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Import Data and Overview</a></span><ul class="toc-item"><li><span><a href="#Read-data-dictionary" data-toc-modified-id="Read-data-dictionary-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Read data dictionary</a></span></li><li><span><a href="#Look-at-heads-and-tails-of-the-two-data-sets" data-toc-modified-id="Look-at-heads-and-tails-of-the-two-data-sets-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Look at heads and tails of the two data sets</a></span></li><li><span><a href="#&quot;Forced&quot;-description-of-data-sets" data-toc-modified-id="&quot;Forced&quot;-description-of-data-sets-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>"Forced" description of data sets</a></span></li><li><span><a href="#Initial-appreciation-of-data,-before-cleaning-starts" data-toc-modified-id="Initial-appreciation-of-data,-before-cleaning-starts-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Initial appreciation of data, before cleaning starts</a></span><ul class="toc-item"><li><span><a href="#Using-pair-plots" data-toc-modified-id="Using-pair-plots-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Using pair plots</a></span></li><li><span><a href="#Using-correlation-heatmap" data-toc-modified-id="Using-correlation-heatmap-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Using correlation heatmap</a></span></li></ul></li></ul></li><li><span><a href="#Data-Cleaning" data-toc-modified-id="Data-Cleaning-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Data Cleaning</a></span><ul class="toc-item"><li><span><a href="#Cleaning-strategy" data-toc-modified-id="Cleaning-strategy-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Cleaning strategy</a></span></li><li><span><a href="#Convert-column-names" data-toc-modified-id="Convert-column-names-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Convert column names</a></span></li><li><span><a href="#Check-dtypes-and-convert-if-necessary" data-toc-modified-id="Check-dtypes-and-convert-if-necessary-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Check dtypes and convert if necessary</a></span></li><li><span><a href="#Check-for-null-values" data-toc-modified-id="Check-for-null-values-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Check for null values</a></span><ul class="toc-item"><li><span><a href="#pool_qc" data-toc-modified-id="pool_qc-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>pool_qc</a></span></li><li><span><a href="#Create-tracking-table-for-converted-ordinal-variables" data-toc-modified-id="Create-tracking-table-for-converted-ordinal-variables-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Create tracking table for converted ordinal variables</a></span></li><li><span><a href="#misc_feature" data-toc-modified-id="misc_feature-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>misc_feature</a></span></li><li><span><a href="#alley" data-toc-modified-id="alley-4.4.4"><span class="toc-item-num">4.4.4&nbsp;&nbsp;</span>alley</a></span></li><li><span><a href="#fence" data-toc-modified-id="fence-4.4.5"><span class="toc-item-num">4.4.5&nbsp;&nbsp;</span>fence</a></span></li><li><span><a href="#fireplace_qu" data-toc-modified-id="fireplace_qu-4.4.6"><span class="toc-item-num">4.4.6&nbsp;&nbsp;</span>fireplace_qu</a></span></li><li><span><a href="#lot_frontage" data-toc-modified-id="lot_frontage-4.4.7"><span class="toc-item-num">4.4.7&nbsp;&nbsp;</span>lot_frontage</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Ames Housing Project by Ethan Leow

# %% [markdown]
# (this notebook was created with the help of Nbextensions' "Table of Contents (2)" and is best viewed / navigated by enabling the extension)

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# To come up with a high accuracy model to predict house prices in Ames, IA and to understand the drivers of house prices

# %% [markdown]
# ## Import Libraries

# %%
# import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Import Data and Overview

# %%
# Read data
train = pd.read_csv("../datasets/train.csv")
test = pd.read_csv("../datasets/test.csv")

# %% [markdown]
# ### Read data dictionary

# %% [markdown]
# Look at data dictionary (source: Dean De Cock, Truman State University):
# __[data dictionary](http://jse.amstat.org/v19n3/decock/DataDocumentation.txt)__
# I shall be editing and adding to this dictionary after data cleaning is over.

# %% [markdown]
# ### Look at heads and tails of the two data sets

# %%
# Look at heads and tails of data sets
train
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      109  533352170           60        RL           NaN     13517   Pave
# 1      544  531379050           60        RL          43.0     11492   Pave
# 2      153  535304180           20        RL          68.0      7922   Pave
# 3      318  916386060           60        RL          73.0      9802   Pave
# 4      255  906425045           50        RL          82.0     14235   Pave
# ...    ...        ...          ...       ...           ...       ...    ...
# 2046  1587  921126030           20        RL          79.0     11449   Pave
# 2047   785  905377130           30        RL           NaN     12342   Pave
# 2048   916  909253010           50        RL          57.0      7558   Pave
# 2049   639  535179160           20        RL          80.0     10400   Pave
# 2050    10  527162130           60        RL          60.0      7500   Pave
#
#      Alley Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC Fence  \
# 0      NaN       IR1          Lvl  ...            0         0     NaN   NaN
# 1      NaN       IR1          Lvl  ...            0         0     NaN   NaN
# 2      NaN       Reg          Lvl  ...            0         0     NaN   NaN
# 3      NaN       Reg          Lvl  ...            0         0     NaN   NaN
# 4      NaN       IR1          Lvl  ...            0         0     NaN   NaN
# ...    ...       ...          ...  ...          ...       ...     ...   ...
# 2046   NaN       IR1          HLS  ...            0         0     NaN   NaN
# 2047   NaN       IR1          Lvl  ...            0         0     NaN   NaN
# 2048   NaN       Reg          Bnk  ...            0         0     NaN   NaN
# 2049   NaN       Reg          Lvl  ...            0         0     NaN   NaN
# 2050   NaN       Reg          Lvl  ...            0         0     NaN   NaN
#
#      Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice
# 0             NaN        0       3    2010        WD      130500
# 1             NaN        0       4    2009        WD      220000
# 2             NaN        0       1    2010        WD      109000
# 3             NaN        0       4    2010        WD      174000
# 4             NaN        0       3    2010        WD      138500
# ...           ...      ...     ...     ...        ...        ...
# 2046          NaN        0       1    2008        WD      298751
# 2047          NaN        0       3    2009        WD       82500
# 2048          NaN        0       3    2009        WD      177000
# 2049          NaN        0      11    2009        WD      144000
# 2050          NaN        0       6    2010        WD      189000
#
# [2051 rows x 81 columns]

# %%
test
# Out:
#        Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0    2658  902301120          190        RM          69.0      9142   Pave
# 1    2718  905108090           90        RL           NaN      9662   Pave
# 2    2414  528218130           60        RL          58.0     17104   Pave
# 3    1989  902207150           30        RM          60.0      8520   Pave
# 4     625  535105100           20        RL           NaN      9500   Pave
# ..    ...        ...          ...       ...           ...       ...    ...
# 873  1662  527377110           60        RL          80.0      8000   Pave
# 874  1234  535126140           60        RL          90.0     14670   Pave
# 875  1373  904100040           20        RL          55.0      8250   Pave
# 876  1672  527425140           20        RL          60.0      9000   Pave
# 877  1939  535327160           20        RL          70.0      8400   Pave
#
#     Alley Lot Shape Land Contour  ... 3Ssn Porch Screen Porch Pool Area  \
# 0    Grvl       Reg          Lvl  ...          0            0         0
# 1     NaN       IR1          Lvl  ...          0            0         0
# 2     NaN       IR1          Lvl  ...          0            0         0
# 3     NaN       Reg          Lvl  ...          0            0         0
# 4     NaN       IR1          Lvl  ...          0          185         0
# ..    ...       ...          ...  ...        ...          ...       ...
# 873   NaN       Reg          Lvl  ...          0            0         0
# 874   NaN       Reg          Lvl  ...          0            0         0
# 875   NaN       Reg          Lvl  ...          0            0         0
# 876   NaN       Reg          Lvl  ...          0            0         0
# 877   NaN       Reg          Lvl  ...          0            0         0
#
#     Pool QC  Fence Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type
# 0       NaN    NaN          NaN        0       4     2006        WD
# 1       NaN    NaN          NaN        0       8     2006        WD
# 2       NaN    NaN          NaN        0       9     2006        New
# 3       NaN    NaN          NaN        0       7     2007        WD
# 4       NaN    NaN          NaN        0       7     2009        WD
# ..      ...    ...          ...      ...     ...      ...        ...
# 873     NaN    NaN          NaN        0      11     2007        WD
# 874     NaN  MnPrv          NaN        0       8     2008        WD
# 875     NaN    NaN          NaN        0       8     2008        WD
# 876     NaN   GdWo          NaN        0       5     2007        WD
# 877     NaN   GdWo          NaN        0       3     2007        WD
#
# [878 rows x 80 columns]

# %% [markdown]
# Train has 2051 rows and 81 columns, while Test has 878 and 80 columns.
# In line with expectations, as the Test set is supposed to have one less column than Train set.
# Confirmed when I scroll to the right, that the "SalePrice" column is missing for Test.

# %% [markdown]
# ### "Forced" description of data sets

# %%
# Set all columns and rows to max for describe() dataset
pd.set_option('max_columns',None)
pd.set_option('max_rows',None)

# %%
# Describe train set, including categorical and nominal variables
train.describe(include = 'all')
# Out:
#                  Id           PID  MS SubClass MS Zoning  Lot Frontage  \
# count   2051.000000  2.051000e+03  2051.000000      2051   1721.000000
# unique          NaN           NaN          NaN         7           NaN
# top             NaN           NaN          NaN        RL           NaN
# freq            NaN           NaN          NaN      1598           NaN
# mean    1474.033642  7.135900e+08    57.008776       NaN     69.055200
# std      843.980841  1.886918e+08    42.824223       NaN     23.260653
# min        1.000000  5.263011e+08    20.000000       NaN     21.000000
# 25%      753.500000  5.284581e+08    20.000000       NaN     58.000000
# 50%     1486.000000  5.354532e+08    50.000000       NaN     68.000000
# 75%     2198.000000  9.071801e+08    70.000000       NaN     80.000000
# max     2930.000000  9.241520e+08   190.000000       NaN    313.000000
#
#              Lot Area Street Alley Lot Shape Land Contour Utilities  \
# count     2051.000000   2051   140      2051         2051      2051
# unique            NaN      2     2         4            4         3
# top               NaN   Pave  Grvl       Reg          Lvl    AllPub
# freq              NaN   2044    85      1295         1843      2049
# mean     10065.208191    NaN   NaN       NaN          NaN       NaN
# std       6742.488909    NaN   NaN       NaN          NaN       NaN
# min       1300.000000    NaN   NaN       NaN          NaN       NaN
# 25%       7500.000000    NaN   NaN       NaN          NaN       NaN
# 50%       9430.000000    NaN   NaN       NaN          NaN       NaN
# 75%      11513.500000    NaN   NaN       NaN          NaN       NaN
# max     159000.000000    NaN   NaN       NaN          NaN       NaN
#
#        Lot Config Land Slope Neighborhood Condition 1 Condition 2 Bldg Type  \
# count        2051       2051         2051        2051        2051      2051
# unique          5          3           28           9           8         5
# top        Inside        Gtl        NAmes        Norm        Norm      1Fam
# freq         1503       1953          310        1767        2025      1700
# mean          NaN        NaN          NaN         NaN         NaN       NaN
# std           NaN        NaN          NaN         NaN         NaN       NaN
# min           NaN        NaN          NaN         NaN         NaN       NaN
# 25%           NaN        NaN          NaN         NaN         NaN       NaN
# 50%           NaN        NaN          NaN         NaN         NaN       NaN
# 75%           NaN        NaN          NaN         NaN         NaN       NaN
# max           NaN        NaN          NaN         NaN         NaN       NaN
#
#        House Style  Overall Qual  Overall Cond   Year Built  Year Remod/Add  \
# count         2051   2051.000000   2051.000000  2051.000000     2051.000000
# unique           8           NaN           NaN          NaN             NaN
# top         1Story           NaN           NaN          NaN             NaN
# freq          1059           NaN           NaN          NaN             NaN
# mean           NaN      6.112140      5.562165  1971.708922     1984.190151
# std            NaN      1.426271      1.104497    30.177889       21.036250
# min            NaN      1.000000      1.000000  1872.000000     1950.000000
# 25%            NaN      5.000000      5.000000  1953.500000     1964.500000
# 50%            NaN      6.000000      5.000000  1974.000000     1993.000000
# 75%            NaN      7.000000      6.000000  2001.000000     2004.000000
# max            NaN     10.000000      9.000000  2010.000000     2010.000000
#
#        Roof Style Roof Matl Exterior 1st Exterior 2nd Mas Vnr Type  \
# count        2051      2051         2051         2051         2029
# unique          6         6           15           15            4
# top         Gable   CompShg      VinylSd      VinylSd         None
# freq         1619      2025          724          721         1218
# mean          NaN       NaN          NaN          NaN          NaN
# std           NaN       NaN          NaN          NaN          NaN
# min           NaN       NaN          NaN          NaN          NaN
# 25%           NaN       NaN          NaN          NaN          NaN
# 50%           NaN       NaN          NaN          NaN          NaN
# 75%           NaN       NaN          NaN          NaN          NaN
# max           NaN       NaN          NaN          NaN          NaN
#
#         Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual Bsmt Cond  \
# count    2029.000000       2051       2051       2051      1996      1996
# unique           NaN          4          5          6         5         5
# top              NaN         TA         TA      PConc        TA        TA
# freq             NaN       1247       1778        926       887      1834
# mean       99.695909        NaN        NaN        NaN       NaN       NaN
# std       174.963129        NaN        NaN        NaN       NaN       NaN
# min         0.000000        NaN        NaN        NaN       NaN       NaN
# 25%         0.000000        NaN        NaN        NaN       NaN       NaN
# 50%         0.000000        NaN        NaN        NaN       NaN       NaN
# 75%       161.000000        NaN        NaN        NaN       NaN       NaN
# max      1600.000000        NaN        NaN        NaN       NaN       NaN
#
#        Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# count           1993           1996   2050.000000           1995
# unique             4              6           NaN              6
# top               No            GLQ           NaN            Unf
# freq            1339            615           NaN           1749
# mean             NaN            NaN    442.300488            NaN
# std              NaN            NaN    461.204124            NaN
# min              NaN            NaN      0.000000            NaN
# 25%              NaN            NaN      0.000000            NaN
# 50%              NaN            NaN    368.000000            NaN
# 75%              NaN            NaN    733.750000            NaN
# max              NaN            NaN   5644.000000            NaN
#
#         BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC  \
# count    2050.000000  2050.000000    2050.000000    2051       2051
# unique           NaN          NaN            NaN       5          5
# top              NaN          NaN            NaN    GasA         Ex
# freq             NaN          NaN            NaN    2018       1065
# mean       47.959024   567.728293    1057.987805     NaN        NaN
# std       165.000901   444.954786     449.410704     NaN        NaN
# min         0.000000     0.000000       0.000000     NaN        NaN
# 25%         0.000000   220.000000     793.000000     NaN        NaN
# 50%         0.000000   474.500000     994.500000     NaN        NaN
# 75%         0.000000   811.000000    1318.750000     NaN        NaN
# max      1474.000000  2336.000000    6110.000000     NaN        NaN
#
#        Central Air Electrical   1st Flr SF   2nd Flr SF  Low Qual Fin SF  \
# count         2051       2051  2051.000000  2051.000000      2051.000000
# unique           2          5          NaN          NaN              NaN
# top              Y      SBrkr          NaN          NaN              NaN
# freq          1910       1868          NaN          NaN              NaN
# mean           NaN        NaN  1164.488055   329.329108         5.512921
# std            NaN        NaN   396.446923   425.671046        51.068870
# min            NaN        NaN   334.000000     0.000000         0.000000
# 25%            NaN        NaN   879.500000     0.000000         0.000000
# 50%            NaN        NaN  1093.000000     0.000000         0.000000
# 75%            NaN        NaN  1405.000000   692.500000         0.000000
# max            NaN        NaN  5095.000000  1862.000000      1064.000000
#
#         Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath    Full Bath    Half Bath  \
# count   2051.000000     2049.000000     2049.000000  2051.000000  2051.000000
# unique          NaN             NaN             NaN          NaN          NaN
# top             NaN             NaN             NaN          NaN          NaN
# freq            NaN             NaN             NaN          NaN          NaN
# mean    1499.330083        0.427526        0.063446     1.577279     0.371039
# std      500.447829        0.522673        0.251705     0.549279     0.501043
# min      334.000000        0.000000        0.000000     0.000000     0.000000
# 25%     1129.000000        0.000000        0.000000     1.000000     0.000000
# 50%     1444.000000        0.000000        0.000000     2.000000     0.000000
# 75%     1728.500000        1.000000        0.000000     2.000000     1.000000
# max     5642.000000        3.000000        2.000000     4.000000     2.000000
#
#         Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  \
# count     2051.000000    2051.000000         2051    2051.000000       2051
# unique            NaN            NaN            4            NaN          8
# top               NaN            NaN           TA            NaN        Typ
# freq              NaN            NaN         1047            NaN       1915
# mean         2.843491       1.042906          NaN       6.435885        NaN
# std          0.826618       0.209790          NaN       1.560225        NaN
# min          0.000000       0.000000          NaN       2.000000        NaN
# 25%          2.000000       1.000000          NaN       5.000000        NaN
# 50%          3.000000       1.000000          NaN       6.000000        NaN
# 75%          3.000000       1.000000          NaN       7.000000        NaN
# max          8.000000       3.000000          NaN      15.000000        NaN
#
#          Fireplaces Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  \
# count   2051.000000         1051        1938    1937.000000          1937
# unique          NaN            5           6            NaN             3
# top             NaN           Gd      Attchd            NaN           Unf
# freq            NaN          523        1213            NaN           849
# mean       0.590931          NaN         NaN    1978.707796           NaN
# std        0.638516          NaN         NaN      25.441094           NaN
# min        0.000000          NaN         NaN    1895.000000           NaN
# 25%        0.000000          NaN         NaN    1961.000000           NaN
# 50%        1.000000          NaN         NaN    1980.000000           NaN
# 75%        1.000000          NaN         NaN    2002.000000           NaN
# max        4.000000          NaN         NaN    2207.000000           NaN
#
#         Garage Cars  Garage Area Garage Qual Garage Cond Paved Drive  \
# count   2050.000000  2050.000000        1937        1937        2051
# unique          NaN          NaN           5           5           3
# top             NaN          NaN          TA          TA           Y
# freq            NaN          NaN        1832        1868        1861
# mean       1.776585   473.671707         NaN         NaN         NaN
# std        0.764537   215.934561         NaN         NaN         NaN
# min        0.000000     0.000000         NaN         NaN         NaN
# 25%        1.000000   319.000000         NaN         NaN         NaN
# 50%        2.000000   480.000000         NaN         NaN         NaN
# 75%        2.000000   576.000000         NaN         NaN         NaN
# max        5.000000  1418.000000         NaN         NaN         NaN
#
#         Wood Deck SF  Open Porch SF  Enclosed Porch   3Ssn Porch  \
# count    2051.000000    2051.000000     2051.000000  2051.000000
# unique           NaN            NaN             NaN          NaN
# top              NaN            NaN             NaN          NaN
# freq             NaN            NaN             NaN          NaN
# mean       93.833740      47.556802       22.571916     2.591419
# std       128.549416      66.747241       59.845110    25.229615
# min         0.000000       0.000000        0.000000     0.000000
# 25%         0.000000       0.000000        0.000000     0.000000
# 50%         0.000000      27.000000        0.000000     0.000000
# 75%       168.000000      70.000000        0.000000     0.000000
# max      1424.000000     547.000000      432.000000   508.000000
#
#         Screen Porch    Pool Area Pool QC  Fence Misc Feature      Misc Val  \
# count    2051.000000  2051.000000       9    400           65   2051.000000
# unique           NaN          NaN       4      4            5           NaN
# top              NaN          NaN      Gd  MnPrv         Shed           NaN
# freq             NaN          NaN       4    227           56           NaN
# mean       16.511458     2.397855     NaN    NaN          NaN     51.574354
# std        57.374204    37.782570     NaN    NaN          NaN    573.393985
# min         0.000000     0.000000     NaN    NaN          NaN      0.000000
# 25%         0.000000     0.000000     NaN    NaN          NaN      0.000000
# 50%         0.000000     0.000000     NaN    NaN          NaN      0.000000
# 75%         0.000000     0.000000     NaN    NaN          NaN      0.000000
# max       490.000000   800.000000     NaN    NaN          NaN  17000.000000
#
#             Mo Sold      Yr Sold Sale Type      SalePrice
# count   2051.000000  2051.000000      2051    2051.000000
# unique          NaN          NaN         9            NaN
# top             NaN          NaN       WD             NaN
# freq            NaN          NaN      1781            NaN
# mean       6.219893  2007.775719       NaN  181469.701609
# std        2.744736     1.312014       NaN   79258.659352
# min        1.000000  2006.000000       NaN   12789.000000
# 25%        4.000000  2007.000000       NaN  129825.000000
# 50%        6.000000  2008.000000       NaN  162500.000000
# 75%        8.000000  2009.000000       NaN  214000.000000
# max       12.000000  2010.000000       NaN  611657.000000

# %% [markdown]
# <a id='initial_appreciation_of_data'></a>
# ### Initial appreciation of data, before cleaning starts

# %% [markdown]
# #### Using pair plots

# %%
# First cut look of numeric variable, using sns.pairplot()
# DO NOT RUN THE BELOW COMMAND UNLESS YOU HAVE TIME, WILL TAKE MORE THAN 30 MINS!!

# sns.pairplot(train.select_dtypes(include=['float64', 'int64']))

# A .png file has been saved in ../images for us to review at our leisure anytime

# %% [markdown]
# ![Pairplot of all numeric variables in Train set - First Cut](../images/train_numeric_pairplot.png)

# %% [markdown]
# - Plot of "Sale Price" against all continuous variables, and categorical variables that are encoded as numbers
#     - We start to see some rough patterns...and potential outliers to fix during data cleaning later
#     - Things to mentally take note of:
#         - Lot frontage: Slightly upward trend where larger lot frontage equates to higher prices. 2 potential outliers where lot frontage are extremely large but prices are low
#         - Lot area: Same issue with 2 possible outliers where transacted prices look too low for the lot sizes
#         - Overall qual: Definitely ordinal with 10 discrete vertical lines. Must keep this variable, as it looks well behaved with higher sale prices for higher quality.
#         - Overall cond: Weird vertical line at value of "5", prices stretch from the min to max. Might be the case that people just put "5" as a default regardless of how good the house is. All other values (1-4, 6-10) look fine, with an upward sloping relationship to price.
#         - Year built: Can keep, upward sloping relationship
#         - Year remodeled: Upward sloping relationship, can possibly keep this variable if not too correlated with year_built
#         - Mas Vnr Area: Nothing interesting, no obvious relationship
#         - BsmtFin SF 1: Two outliers (>4000 sqft) with no obvious increase in price even though size is so large.
#         - BsmtFin SF2, Bsmt Unf SF: No obvious relationship, may drop later if its data is not clean
#         - Total Bsmt SF: Can keep, strong upward sloping relationship. Must fix two outliers (~5000 sqft and ~6000 sqft) that did not show correspondingly large sales prices
#         - 1st Flr SF: Can keep, strong upward sloping relationship. 2-3 potential outliers to fix.
#         - 2nd Flr SF: Interesting data series. I see the full range of sale prices (min to max) clustered at the SF=0 value (i.e. vertical line), and an upward sloping relationship between price and SF for SF >100. We need to transform this variable, otherwise the regression coefficient will be messed up by all the sale prices at SF=0. Perhaps create dummy + interaction variables during the cleaning stage later, or simply add 1st Flr SF to 2nd Flr SF?
#         - Low Qual Fin SF: Can drop later, no obvious relationship
#         - Gr Liv Area: Good variable to keep, need to fix two outliers for area > 5000sqft. To check on correlation with 1st_Flr_SF and 2nd_Flr_SF later, if it is high, maybe we don't need the latter two variables for our regression.
#         - Bsmt Full Bath, Half Bath: Nothing interesting here.
#         - Full Bath: Can possibly keep, upward sloping relationship
#         - Bedroom AbvGr, Kitchen AbvGr: Nothing obvious here
#         - TotRms AbvGrd: Can keep, but 3 possible outliers (13-15 rooms) with less than average prices
#         - Fireplaces: Weakly upward sloping relationship
#         - GarageYr Blt: Upward sloping, but 1 obvious outlier / data error to correct (built around 2200!)
#         - Garage Cars / Garage Area: Both upward sloping, can keep, but need to see corr matrix below to decide if it's better to drop one of them to avoid collinearity issues
#         - Wood Deck SF, Open Porch SF: No obvious relationship
#         - Enclosed Porch, 3Ssn Porch, Screen Porch, Pool Area: No obvious relationship
#         - Misc Val: No obvious relationship
#         - Month Sold: No obvious relationship
#         - Year Sold: No obvious relationship, but probably better to keep it in to account for possible time trend, or dummify it to account for 2008-2010's recession / foreclosures??

# %% [markdown]
# #### Using correlation heatmap

# %%
# Plot correlation heatmap to substantiate prelim findings
# Like the pairplot above, this is a very rough first cut, as we have not cleaned the data yet,
# and we have not converted or transformed nominal and 
corr = train.select_dtypes(include=['float64', 'int64']).corr()

plt.figure(figsize=(20,15)) 

sns.heatmap(
    data = corr, 
#    annot = True,
    linewidths = 3,
    cmap = "coolwarm",
    mask = np.triu(np.ones_like(corr, dtype=bool))
);

# %% [markdown]
# Correlation heat map confirms some of the observations seen in sns.pairplot. A few things to note during cleaning and EDA later:
# - Garage Cars and Garage Area have extremely high correlation, so we can drop one during data cleaning, whichever has lower quality data (e.g. more NAs)
# - TotalRms AveGrd and Gr Liv Area have very high correlation, but pairplot shows Gr Liv Area having tighter (less dispersed) datapoints than TotalRms when plotted against Sales Price, maybe it is better to drop TotalRms.
# - Garage Yr Blt and Year Blt have very high correlation, and strong relationship against sale price in the pair plots. Makes sense since most houses and their garages should be built at the same time, so we should probably drop Garage Yr Blt to avoid collinearity issues if it has more Null values than Year Blt (to double confirm during data cleaning stage)
# - Total Bsmt SF and 1st Flr SF have high correlation, can consider dropping 1st Flr SF as both show upward sloping relationship with Sale Price. 1st Flr SF is also correlated with Gr Liv Area, but Gr Liv Area is not as correlated with Total Bsmt SF, so we are not losing valuable info by dropping 1st Flr SF and retaining both Total Bsmt SF and Gr Liv Area.
# - In general, as a first cut, we can see the following variables being strong indicators of sale prices:
#     - Overall Qual
#     - Year Built
#     - Year Remod/Add
#     - Mas Vnr Area
#     - Total Bsmt SF
#     - Gr Liv Area
#     - Full Bath
#     - Garage Area

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Cleaning strategy
#
# My first step is to use deductive imputation to see if we can use logic to fill in null values. This requires reading the [data dictionary](http://jse.amstat.org/v19n3/decock/DataDocumentation.txt) provided by Dean De Cock.
#
# If deductive imputation does not work, instead of jumping to mean/median/mode imputation, I shall look at the results of my first-cut look of pair plots and correlation heatmap in the [initial appreciation of data](#initial_appreciation_of_data) section above. If a variable with null values is highly correlated with another variable that does not, we can drop the troublesome variable. If a variable has a lot of null values and does not seem to exhibit any relationship with sale price in the pair plot, we can also drop it. The reason is that mean/median/mode imputation can significantly distort the histogram and underestimate variance of the variable, and should be used only if we are reasonably confident data is MCAR.
#
# Finally, I shall also consider using regression imputation if there are other variables that are fully observed, only if it reduces the MSE of my model.

# %% [markdown]
# ### Convert column names

# %%
# Convert all columns naming to lowercase and replace spaces with underscores
train.columns = [x.lower().replace(' ','_') for x in train.columns]
test.columns = [x.lower().replace(' ','_') for x in test.columns]

# %%
# Check
train.columns, test.columns
# Out:
# (Index(['id', 'pid', 'ms_subclass', 'ms_zoning', 'lot_frontage', 'lot_area',
#         'street', 'alley', 'lot_shape', 'land_contour', 'utilities',
#         'lot_config', 'land_slope', 'neighborhood', 'condition_1',
#         'condition_2', 'bldg_type', 'house_style', 'overall_qual',
#         'overall_cond', 'year_built', 'year_remod/add', 'roof_style',
#         'roof_matl', 'exterior_1st', 'exterior_2nd', 'mas_vnr_type',
#         'mas_vnr_area', 'exter_qual', 'exter_cond', 'foundation', 'bsmt_qual',
#         'bsmt_cond', 'bsmt_exposure', 'bsmtfin_type_1', 'bsmtfin_sf_1',
#         'bsmtfin_type_2', 'bsmtfin_sf_2', 'bsmt_unf_sf', 'total_bsmt_sf',
#         'heating', 'heating_qc', 'central_air', 'electrical', '1st_flr_sf',
#         '2nd_flr_sf', 'low_qual_fin_sf', 'gr_liv_area', 'bsmt_full_bath',
#         'bsmt_half_bath', 'full_bath', 'half_bath', 'bedroom_abvgr',
#         'kitchen_abvgr', 'kitchen_qual', 'totrms_abvgrd', 'functional',
#         'fireplaces', 'fireplace_qu', 'garage_type', 'garage_yr_blt',
#         'garage_finish', 'garage_cars', 'garage_area', 'garage_qual',
#         'garage_cond', 'paved_drive', 'wood_deck_sf', 'open_porch_sf',
#         'enclosed_porch', '3ssn_porch', 'screen_porch', 'pool_area', 'pool_qc',
#         'fence', 'misc_feature', 'misc_val', 'mo_sold', 'yr_sold', 'sale_type',
#         'saleprice'],
#        dtype='object'),
#  Index(['id', 'pid', 'ms_subclass', 'ms_zoning', 'lot_frontage', 'lot_area',
#         'street', 'alley', 'lot_shape', 'land_contour', 'utilities',
#         'lot_config', 'land_slope', 'neighborhood', 'condition_1',
#         'condition_2', 'bldg_type', 'house_style', 'overall_qual',
#         'overall_cond', 'year_built', 'year_remod/add', 'roof_style',
#         'roof_matl', 'exterior_1st', 'exterior_2nd', 'mas_vnr_type',
#         'mas_vnr_area', 'exter_qual', 'exter_cond', 'foundation', 'bsmt_qual',
#         'bsmt_cond', 'bsmt_exposure', 'bsmtfin_type_1', 'bsmtfin_sf_1',
#         'bsmtfin_type_2', 'bsmtfin_sf_2', 'bsmt_unf_sf', 'total_bsmt_sf',
#         'heating', 'heating_qc', 'central_air', 'electrical', '1st_flr_sf',
#         '2nd_flr_sf', 'low_qual_fin_sf', 'gr_liv_area', 'bsmt_full_bath',
#         'bsmt_half_bath', 'full_bath', 'half_bath', 'bedroom_abvgr',
#         'kitchen_abvgr', 'kitchen_qual', 'totrms_abvgrd', 'functional',
#         'fireplaces', 'fireplace_qu', 'garage_type', 'garage_yr_blt',
#         'garage_finish', 'garage_cars', 'garage_area', 'garage_qual',
#         'garage_cond', 'paved_drive', 'wood_deck_sf', 'open_porch_sf',
#         'enclosed_porch', '3ssn_porch', 'screen_porch', 'pool_area', 'pool_qc',
#         'fence', 'misc_feature', 'misc_val', 'mo_sold', 'yr_sold', 'sale_type'],
#        dtype='object'))

# %% [markdown]
# ### Check dtypes and convert if necessary

# %%
# Check dtypes by count
print("train set \n", train.dtypes.value_counts())
print("")
print("test set \n", test.dtypes.value_counts())
# Out:
# train set
#  object     42
# int64      28
# float64    11
# dtype: int64
#
# test set
#  object     42
# int64      35
# float64     3
# dtype: int64

# %%
# Convert strings to float, int64 to datetime, if necessary

# Check columns to see if strings should be converted to float/int
train.select_dtypes(include=['object']).head()
# Out:
#   ms_zoning street alley lot_shape land_contour utilities lot_config  \
# 0        RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 1        RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 2        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 3        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 4        RL   Pave   NaN       IR1          Lvl    AllPub     Inside
#
#   land_slope neighborhood condition_1 condition_2 bldg_type house_style  \
# 0        Gtl       Sawyer        RRAe        Norm      1Fam      2Story
# 1        Gtl      SawyerW        Norm        Norm      1Fam      2Story
# 2        Gtl        NAmes        Norm        Norm      1Fam      1Story
# 3        Gtl       Timber        Norm        Norm      1Fam      2Story
# 4        Gtl      SawyerW        Norm        Norm      1Fam      1.5Fin
#
#   roof_style roof_matl exterior_1st exterior_2nd mas_vnr_type exter_qual  \
# 0      Gable   CompShg      HdBoard      Plywood      BrkFace         Gd
# 1      Gable   CompShg      VinylSd      VinylSd      BrkFace         Gd
# 2      Gable   CompShg      VinylSd      VinylSd         None         TA
# 3      Gable   CompShg      VinylSd      VinylSd         None         TA
# 4      Gable   CompShg      Wd Sdng      Plywood         None         TA
#
#   exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  \
# 0         TA     CBlock        TA        TA            No            GLQ
# 1         TA      PConc        Gd        TA            No            GLQ
# 2         Gd     CBlock        TA        TA            No            GLQ
# 3         TA      PConc        Gd        TA            No            Unf
# 4         TA      PConc        Fa        Gd            No            Unf
#
#   bsmtfin_type_2 heating heating_qc central_air electrical kitchen_qual  \
# 0            Unf    GasA         Ex           Y      SBrkr           Gd
# 1            Unf    GasA         Ex           Y      SBrkr           Gd
# 2            Unf    GasA         TA           Y      SBrkr           Gd
# 3            Unf    GasA         Gd           Y      SBrkr           TA
# 4            Unf    GasA         TA           Y      SBrkr           TA
#
#   functional fireplace_qu garage_type garage_finish garage_qual garage_cond  \
# 0        Typ          NaN      Attchd           RFn          TA          TA
# 1        Typ           TA      Attchd           RFn          TA          TA
# 2        Typ          NaN      Detchd           Unf          TA          TA
# 3        Typ          NaN     BuiltIn           Fin          TA          TA
# 4        Typ          NaN      Detchd           Unf          TA          TA
#
#   paved_drive pool_qc fence misc_feature sale_type
# 0           Y     NaN   NaN          NaN       WD
# 1           Y     NaN   NaN          NaN       WD
# 2           Y     NaN   NaN          NaN       WD
# 3           Y     NaN   NaN          NaN       WD
# 4           N     NaN   NaN          NaN       WD

# %% [markdown]
# Looks good above, none of the columns in train set are not numerical values that are accidentally read in as strings.

# %%
# Repeat exercise for test set
test.select_dtypes(include=['object']).head()
# Out:
#   ms_zoning street alley lot_shape land_contour utilities lot_config  \
# 0        RM   Pave  Grvl       Reg          Lvl    AllPub     Inside
# 1        RL   Pave   NaN       IR1          Lvl    AllPub     Inside
# 2        RL   Pave   NaN       IR1          Lvl    AllPub     Inside
# 3        RM   Pave   NaN       Reg          Lvl    AllPub     Inside
# 4        RL   Pave   NaN       IR1          Lvl    AllPub     Inside
#
#   land_slope neighborhood condition_1 condition_2 bldg_type house_style  \
# 0        Gtl      OldTown        Norm        Norm    2fmCon      2Story
# 1        Gtl       Sawyer        Norm        Norm    Duplex      1Story
# 2        Gtl      Gilbert        Norm        Norm      1Fam      2Story
# 3        Gtl      OldTown        Norm        Norm      1Fam      1Story
# 4        Gtl        NAmes        Norm        Norm      1Fam      1Story
#
#   roof_style roof_matl exterior_1st exterior_2nd mas_vnr_type exter_qual  \
# 0      Gable   CompShg      AsbShng      AsbShng         None         TA
# 1      Gable   CompShg      Plywood      Plywood         None         TA
# 2      Gable   CompShg      VinylSd      VinylSd         None         Gd
# 3      Gable   CompShg      Wd Sdng      Wd Sdng         None         Gd
# 4      Gable   CompShg      Plywood      Plywood      BrkFace         TA
#
#   exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  \
# 0         Fa      Stone        Fa        TA            No            Unf
# 1         TA     CBlock        Gd        TA            No            Unf
# 2         TA      PConc        Gd        Gd            Av            GLQ
# 3         TA     CBlock        TA        TA            No            Unf
# 4         TA     CBlock        Gd        TA            No            BLQ
#
#   bsmtfin_type_2 heating heating_qc central_air electrical kitchen_qual  \
# 0            Unf    GasA         Gd           N      FuseP           Fa
# 1            Unf    GasA         TA           Y      SBrkr           TA
# 2            Unf    GasA         Ex           Y      SBrkr           Gd
# 3            Unf    GasA         TA           Y      SBrkr           TA
# 4            Unf    GasA         Gd           Y      SBrkr           TA
#
#   functional fireplace_qu garage_type garage_finish garage_qual garage_cond  \
# 0        Typ          NaN      Detchd           Unf          Po          Po
# 1        Typ          NaN      Attchd           Fin          TA          TA
# 2        Typ           Gd      Attchd           RFn          TA          TA
# 3        Typ          NaN      Detchd           Unf          Fa          TA
# 4        Typ           Gd      Attchd           RFn          TA          TA
#
#   paved_drive pool_qc fence misc_feature sale_type
# 0           Y     NaN   NaN          NaN       WD
# 1           Y     NaN   NaN          NaN       WD
# 2           Y     NaN   NaN          NaN       New
# 3           N     NaN   NaN          NaN       WD
# 4           Y     NaN   NaN          NaN       WD

# %% [markdown]
# Looks good above, none of the columns in test set are not numerical values that are accidentally read in as strings.

# %%
# Check if float64 or int64 need to be converted to datetime
train.select_dtypes(include=['float', 'int']).columns, test.select_dtypes(include=['float', 'int']).columns
# Out:
# (Index(['id', 'pid', 'ms_subclass', 'lot_frontage', 'lot_area', 'overall_qual',
#         'overall_cond', 'year_built', 'year_remod/add', 'mas_vnr_area',
#         'bsmtfin_sf_1', 'bsmtfin_sf_2', 'bsmt_unf_sf', 'total_bsmt_sf',
#         '1st_flr_sf', '2nd_flr_sf', 'low_qual_fin_sf', 'gr_liv_area',
#         'bsmt_full_bath', 'bsmt_half_bath', 'full_bath', 'half_bath',
#         'bedroom_abvgr', 'kitchen_abvgr', 'totrms_abvgrd', 'fireplaces',
#         'garage_yr_blt', 'garage_cars', 'garage_area', 'wood_deck_sf',
#         'open_porch_sf', 'enclosed_porch', '3ssn_porch', 'screen_porch',
#         'pool_area', 'misc_val', 'mo_sold', 'yr_sold', 'saleprice'],
#        dtype='object'),
#  Index(['id', 'pid', 'ms_subclass', 'lot_frontage', 'lot_area', 'overall_qual',
#         'overall_cond', 'year_built', 'year_remod/add', 'mas_vnr_area',
#         'bsmtfin_sf_1', 'bsmtfin_sf_2', 'bsmt_unf_sf', 'total_bsmt_sf',
#         '1st_flr_sf', '2nd_flr_sf', 'low_qual_fin_sf', 'gr_liv_area',
#         'bsmt_full_bath', 'bsmt_half_bath', 'full_bath', 'half_bath',
#         'bedroom_abvgr', 'kitchen_abvgr', 'totrms_abvgrd', 'fireplaces',
#         'garage_yr_blt', 'garage_cars', 'garage_area', 'wood_deck_sf',
#         'open_porch_sf', 'enclosed_porch', '3ssn_porch', 'screen_porch',
#         'pool_area', 'misc_val', 'mo_sold', 'yr_sold'],
#        dtype='object'))

# %% [markdown]
# None of the column names above seem to indicate a need to convert from float/int to datetime.

# %% [markdown]
# ### Check for null values

# %%
# Create columns for number of missing values and percent missing
train_null = pd.DataFrame(
    {'null_count' : train.isnull().sum(),
    'non_null_count' : train.count()
    }
)

train_null["percent_missing"] = train_null.null_count / \
                                (train_null.null_count + train_null.non_null_count)

train_null.sort_values("percent_missing", ascending = False)
# Out:
#                  null_count  non_null_count  percent_missing
# pool_qc                2042               9         0.995612
# misc_feature           1986              65         0.968308
# alley                  1911             140         0.931741
# fence                  1651             400         0.804973
# fireplace_qu           1000            1051         0.487567
# lot_frontage            330            1721         0.160897
# garage_finish           114            1937         0.055583
# garage_qual             114            1937         0.055583
# garage_yr_blt           114            1937         0.055583
# garage_cond             114            1937         0.055583
# garage_type             113            1938         0.055095
# bsmt_exposure            58            1993         0.028279
# bsmtfin_type_2           56            1995         0.027304
# bsmtfin_type_1           55            1996         0.026816
# bsmt_cond                55            1996         0.026816
# bsmt_qual                55            1996         0.026816
# mas_vnr_area             22            2029         0.010726
# mas_vnr_type             22            2029         0.010726
# bsmt_half_bath            2            2049         0.000975
# bsmt_full_bath            2            2049         0.000975
# garage_area               1            2050         0.000488
# total_bsmt_sf             1            2050         0.000488
# bsmt_unf_sf               1            2050         0.000488
# bsmtfin_sf_2              1            2050         0.000488
# bsmtfin_sf_1              1            2050         0.000488
# garage_cars               1            2050         0.000488
# mo_sold                   0            2051         0.000000
# sale_type                 0            2051         0.000000
# full_bath                 0            2051         0.000000
# half_bath                 0            2051         0.000000
# bedroom_abvgr             0            2051         0.000000
# kitchen_abvgr             0            2051         0.000000
# kitchen_qual              0            2051         0.000000
# yr_sold                   0            2051         0.000000
# misc_val                  0            2051         0.000000
# pool_area                 0            2051         0.000000
# screen_porch              0            2051         0.000000
# totrms_abvgrd             0            2051         0.000000
# functional                0            2051         0.000000
# fireplaces                0            2051         0.000000
# 3ssn_porch                0            2051         0.000000
# enclosed_porch            0            2051         0.000000
# open_porch_sf             0            2051         0.000000
# wood_deck_sf              0            2051         0.000000
# gr_liv_area               0            2051         0.000000
# paved_drive               0            2051         0.000000
# id                        0            2051         0.000000
# heating                   0            2051         0.000000
# low_qual_fin_sf           0            2051         0.000000
# overall_qual              0            2051         0.000000
# ms_subclass               0            2051         0.000000
# ms_zoning                 0            2051         0.000000
# lot_area                  0            2051         0.000000
# street                    0            2051         0.000000
# lot_shape                 0            2051         0.000000
# land_contour              0            2051         0.000000
# utilities                 0            2051         0.000000
# lot_config                0            2051         0.000000
# land_slope                0            2051         0.000000
# neighborhood              0            2051         0.000000
# condition_1               0            2051         0.000000
# condition_2               0            2051         0.000000
# bldg_type                 0            2051         0.000000
# house_style               0            2051         0.000000
# overall_cond              0            2051         0.000000
# 2nd_flr_sf                0            2051         0.000000
# year_built                0            2051         0.000000
# year_remod/add            0            2051         0.000000
# roof_style                0            2051         0.000000
# roof_matl                 0            2051         0.000000
# exterior_1st              0            2051         0.000000
# exterior_2nd              0            2051         0.000000
# exter_qual                0            2051         0.000000
# exter_cond                0            2051         0.000000
# foundation                0            2051         0.000000
# pid                       0            2051         0.000000
# heating_qc                0            2051         0.000000
# central_air               0            2051         0.000000
# electrical                0            2051         0.000000
# 1st_flr_sf                0            2051         0.000000
# saleprice                 0            2051         0.000000

# %%
# Repeat for test set
test_null = pd.DataFrame(
    {'null_count' : test.isnull().sum(),
    'non_null_count' : test.count()
    }
)

test_null["percent_missing"] = test_null.null_count / \
                                (test_null.null_count + test_null.non_null_count)

test_null.sort_values("percent_missing", ascending = False)
# Out:
#                  null_count  non_null_count  percent_missing
# pool_qc                 874               4         0.995444
# misc_feature            837              41         0.953303
# alley                   820              58         0.933941
# fence                   706             172         0.804100
# fireplace_qu            422             456         0.480638
# lot_frontage            160             718         0.182232
# garage_yr_blt            45             833         0.051253
# garage_finish            45             833         0.051253
# garage_qual              45             833         0.051253
# garage_cond              45             833         0.051253
# garage_type              44             834         0.050114
# bsmtfin_type_1           25             853         0.028474
# bsmt_qual                25             853         0.028474
# bsmt_cond                25             853         0.028474
# bsmt_exposure            25             853         0.028474
# bsmtfin_type_2           25             853         0.028474
# electrical                1             877         0.001139
# mas_vnr_type              1             877         0.001139
# mas_vnr_area              1             877         0.001139
# kitchen_abvgr             0             878         0.000000
# totrms_abvgrd             0             878         0.000000
# bedroom_abvgr             0             878         0.000000
# half_bath                 0             878         0.000000
# full_bath                 0             878         0.000000
# bsmt_half_bath            0             878         0.000000
# bsmt_full_bath            0             878         0.000000
# gr_liv_area               0             878         0.000000
# kitchen_qual              0             878         0.000000
# id                        0             878         0.000000
# functional                0             878         0.000000
# fireplaces                0             878         0.000000
# 2nd_flr_sf                0             878         0.000000
# garage_cars               0             878         0.000000
# garage_area               0             878         0.000000
# paved_drive               0             878         0.000000
# wood_deck_sf              0             878         0.000000
# open_porch_sf             0             878         0.000000
# enclosed_porch            0             878         0.000000
# 3ssn_porch                0             878         0.000000
# screen_porch              0             878         0.000000
# pool_area                 0             878         0.000000
# misc_val                  0             878         0.000000
# mo_sold                   0             878         0.000000
# yr_sold                   0             878         0.000000
# low_qual_fin_sf           0             878         0.000000
# heating                   0             878         0.000000
# 1st_flr_sf                0             878         0.000000
# lot_config                0             878         0.000000
# house_style               0             878         0.000000
# bldg_type                 0             878         0.000000
# condition_2               0             878         0.000000
# condition_1               0             878         0.000000
# neighborhood              0             878         0.000000
# land_slope                0             878         0.000000
# utilities                 0             878         0.000000
# central_air               0             878         0.000000
# land_contour              0             878         0.000000
# lot_shape                 0             878         0.000000
# street                    0             878         0.000000
# lot_area                  0             878         0.000000
# ms_zoning                 0             878         0.000000
# ms_subclass               0             878         0.000000
# overall_qual              0             878         0.000000
# overall_cond              0             878         0.000000
# year_built                0             878         0.000000
# year_remod/add            0             878         0.000000
# roof_style                0             878         0.000000
# roof_matl                 0             878         0.000000
# exterior_1st              0             878         0.000000
# exterior_2nd              0             878         0.000000
# exter_qual                0             878         0.000000
# exter_cond                0             878         0.000000
# foundation                0             878         0.000000
# bsmtfin_sf_1              0             878         0.000000
# bsmtfin_sf_2              0             878         0.000000
# bsmt_unf_sf               0             878         0.000000
# total_bsmt_sf             0             878         0.000000
# pid                       0             878         0.000000
# heating_qc                0             878         0.000000
# sale_type                 0             878         0.000000

# %% [markdown]
# Summary of findings
# - pool_qc, misc_feature, alley, fence and fireplace_qc are the biggest "offenders", with than 40% missing values
# - lot_frontage is next with 16-18% missing values
# - the remaining variables with missing data can be split into two categories (between 1-5% missing)
#     - Garage-related data, e.g. year built, finish, quality, condition, type
#     - Basement-related data, e.g. finish type, quality, condition, exposure
#     - Masonry veneer data, e.g. area and type
# - the rest are miscellaneous with one or two datapoints missing (<= 1% missing)
#
# I shall start my data cleaning with variables with the highest number of missing values: pool_qc, misc_feature...

# %% [markdown]
# #### pool_qc

# %%
# Check structure 
print("Unique values are", train.pool_qc.unique())
print()
print("Count of null values is", np.sum(train.pool_qc.isnull()))
print()
print("Count of non-null values by type \n", train.pool_qc.value_counts())
# Out:
# Unique values are [nan 'Fa' 'Gd' 'Ex' 'TA']
#
# Count of null values is 2042
#
# Count of non-null values by type
#  Gd    4
# Fa    2
# TA    2
# Ex    1
# Name: pool_qc, dtype: int64

# %% [markdown]
# Dictionary says NA mean No Pool, so we can use deductive imputation here to set null values = "none".
# In addition, the remaining values (Fa, TA, Gd, Ex) have a logical order to them, in terms of increasing quality of pool construction. Therefore, I shall replace categorical values (none, Fa, TA, Gd, Ex) with numerical values (0-1-2-3-4) to reflect ordinal nature of pool quality.

# %%
# Dictionary says NA mean No Pool, and the remaining values have an order in increasing quality
# Replace with numerical values to reflect ordinal nature

dict = {np.nan : 0,
        'Fa' : 1,
        'TA' : 2,
        'Gd' : 3,
        'Ex' : 4
}

train.pool_qc = train.pool_qc.map(dict)

# %%
# Check 1
train.pool_qc.value_counts()
# Out:
# 0    2042
# 3       4
# 1       2
# 2       2
# 4       1
# Name: pool_qc, dtype: int64

# %%
# Check 2
sns.lmplot(data = train, x = "pool_qc", y = "saleprice");

# %% [markdown]
# Conversion from string to number looks correct: higher pool_qc values seem to indicate higher sale prices

# %%
# Repeat for test set
dict = {np.nan : 0,
        'Fa' : 1,
        'TA' : 2,
        'Gd' : 3,
        'Ex' : 4
}

test.pool_qc = test.pool_qc.map(dict)

# Check 
test.pool_qc.value_counts()
# Out:
# 0    874
# 4      3
# 2      1
# Name: pool_qc, dtype: int64

# %% [markdown]
# #### Create tracking table for converted ordinal variables
# I shall create a table to help me keep track of which categorical variables i have transformed from strings to numerical. I expect it to be populated as I clean more categorical variables.
#
# | Variable | Original Categories (in order of quality) | Replacement Numbers (higher is better)|
# |----------|-------------------------------------------|---------------------------------------|
# | pool_qc | NA -> Fa -> TA -> Gd -> Ex | 0-1-2-3-4 |

# %% [markdown]
# #### misc_feature

# %%
# Check structure
print("Unique values are", train.misc_feature.unique())
print()
print("Count of null values is", np.sum(train.misc_feature.isnull()))
print()
print("Count of non-null values by type \n", train.misc_feature.value_counts())
# Out:
# Unique values are [nan 'Shed' 'TenC' 'Gar2' 'Othr' 'Elev']
#
# Count of null values is 1986
#
# Count of non-null values by type
#  Shed    56
# Gar2     4
# Othr     3
# TenC     1
# Elev     1
# Name: misc_feature, dtype: int64

# %% [markdown]
# Dictionary states these are miscellaneous feature not covered in other categories.
#
#        Elev	Elevator
#        Gar2	2nd Garage (if not described in garage section)
#        Othr	Other
#        Shed	Shed (over 100 SF)
#        TenC	Tennis Court
#        NA	None
#
# I shall convert null values to None. The remaining values do not have an order to them, so likely to use one hot encoding to convert them to dummies during EDA.

# %%
# Convert null values to "none"
train.misc_feature.fillna('None', inplace = True)

# %%
# Check 1
train.misc_feature.value_counts()
# Out:
# None    1986
# Shed      56
# Gar2       4
# Othr       3
# TenC       1
# Elev       1
# Name: misc_feature, dtype: int64

# %%
# Check 2
sns.boxplot(data = train, x = "misc_feature", y = "saleprice");

# %%
# Repeat for test set
test.misc_feature.fillna('None', inplace = True)

# Check
test.misc_feature.value_counts()
# Out:
# None    837
# Shed     39
# Othr      1
# Gar2      1
# Name: misc_feature, dtype: int64

# %% [markdown]
# #### alley

# %%
# Check structure
print("Unique values are", train.alley.unique())
print()
print("Count of null values is", np.sum(train.alley.isnull()))
print()
print("Count of non-null values by type \n", train.alley.value_counts())
# Out:
# Unique values are [nan 'Pave' 'Grvl']
#
# Count of null values is 1911
#
# Count of non-null values by type
#  Grvl    85
# Pave    55
# Name: alley, dtype: int64

# %% [markdown]
# Type of alley access to property
#
#        Grvl	Gravel
#        Pave	Paved
#        NA 	No alley access
#
# Dictionary says NA means no access. I shall convert null values to None. The remaining values do not have an order to them, so likely to use one hot encoding to convert them to dummies during EDA.

# %%
# Convert null values to "none"
train.alley.fillna('None', inplace = True)

# %%
# Check 1
train.alley.value_counts()
# Out:
# None    1911
# Grvl      85
# Pave      55
# Name: alley, dtype: int64

# %%
# Check 2
sns.boxplot(data = train, x = "alley", y = "saleprice");

# %%
# Repeat for test set
test.alley.fillna('None', inplace = True)

# Check
test.alley.value_counts()
# Out:
# None    820
# Grvl     35
# Pave     23
# Name: alley, dtype: int64

# %% [markdown]
# #### fence

# %%
# Check structure
print("Unique values are", train.fence.unique())
print()
print("Count of null values is", np.sum(train.fence.isnull()))
print()
print("Count of non-null values by type \n", train.fence.value_counts())
# Out:
# Unique values are [nan 'MnPrv' 'GdPrv' 'GdWo' 'MnWw']
#
# Count of null values is 1651
#
# Count of non-null values by type
#  MnPrv    227
# GdPrv     83
# GdWo      80
# MnWw      10
# Name: fence, dtype: int64

# %% [markdown]
# Fence (Ordinal): Fence quality
#
#        GdPrv	Good Privacy
#        MnPrv	Minimum Privacy
#        GdWo	    Good Wood
#        MnWw	    Minimum Wood/Wire
#        NA	    No Fence
#
# Dictionary says NA means no fence. I shall convert null values to None. The remaining values do really have an order to them (e.g. no relation between good wood vs good privacy), so likely to use one hot encoding to convert them to dummies during EDA.

# %%
# Convert null values to "none"
train.fence.fillna('None', inplace = True)

# %%
# Check 1
train.fence.value_counts()
# Out:
# None     1651
# MnPrv     227
# GdPrv      83
# GdWo       80
# MnWw       10
# Name: fence, dtype: int64

# %%
# Check 2
sns.boxplot(data = train, x = "fence", y = "saleprice");

# %%
# Repeat for test set
test.fence.fillna('None', inplace = True)

# Check
test.fence.value_counts()
# Out:
# None     706
# MnPrv    103
# GdPrv     35
# GdWo      32
# MnWw       2
# Name: fence, dtype: int64

# %% [markdown]
# #### fireplace_qu

# %%
# Check structure
print("Unique values are", train.fireplace_qu.unique())
print()
print("Count of null values is", np.sum(train.fireplace_qu.isnull()))
print()
print("Count of non-null values by type \n", train.fireplace_qu.value_counts())
# Out:
# Unique values are [nan 'TA' 'Gd' 'Po' 'Ex' 'Fa']
#
# Count of null values is 1000
#
# Count of non-null values by type
#  Gd    523
# TA    407
# Fa     59
# Po     31
# Ex     31
# Name: fireplace_qu, dtype: int64

# %% [markdown]
# FireplaceQu (Ordinal): Fireplace quality
#
#        Ex	Excellent - Exceptional Masonry Fireplace
#        Gd	Good - Masonry Fireplace in main level
#        TA	Average - Prefabricated Fireplace in main living area or Masonry Fireplace in basement
#        Fa	Fair - Prefabricated Fireplace in basement
#        Po	Poor - Ben Franklin Stove
#        NA	No Fireplace
#
# Dictionary says NA means no fireplace. The remaining values have an order to them, so will convert to numerical (0-5).

# %%
# Convert NA and categorical values to numerical values
dict = {np.nan : 0,
        'Po' : 1,
        'Fa' : 2,
        'TA' : 3,
        'Gd' : 4,
        'Ex' : 5
}

train.fireplace_qu = train.fireplace_qu.map(dict)

# %%
# Check 1
train.fireplace_qu.value_counts()
# Out:
# 0    1000
# 4     523
# 3     407
# 2      59
# 1      31
# 5      31
# Name: fireplace_qu, dtype: int64

# %%
# Check 2
sns.lmplot(data = train, x = "fireplace_qu", y = "saleprice");

# %% [markdown]
# Conversion from string to number looks correct: higher fireplace_qu values seem to indicate higher sale prices
#
# Update tracking table for converted ordinal variables
#
# | Variable | Original Categories (in order of increasing quality) | Replacement Numbers (higher is better)|
# |----------|-------------------------------------------|---------------------------------------|
# | pool_qc | NA -> Fa -> TA -> Gd -> Ex | 0-1-2-3-4 |
# | fireplace_qu | NA -> Po -> Fa -> TA -> Gd -> Ex | 0-1-2-3-4-5 |

# %%
# Repeat for test set
dict = {np.nan : 0,
        'Po' : 1,
        'Fa' : 2,
        'TA' : 3,
        'Gd' : 4,
        'Ex' : 5
}

test.fireplace_qu = test.fireplace_qu.map(dict)

# Check 
test.fireplace_qu.value_counts()
# Out:
# 0    422
# 4    220
# 3    193
# 2     16
# 1     15
# 5     12
# Name: fireplace_qu, dtype: int64

# %% [markdown]
# #### lot_frontage

# %%
# Check structure
print("Count of null values is", np.sum(train.lot_frontage.isnull()))
print()
print("The structure of non-null values is \n", train.lot_frontage.describe())
# Out:
# Count of null values is 330
#
# The structure of non-null values is
#  count    1721.000000
# mean       69.055200
# std        23.260653
# min        21.000000
# 25%        58.000000
# 50%        68.000000
# 75%        80.000000
# max       313.000000
# Name: lot_frontage, dtype: float64

# %% [markdown]
# Dictionary say Lot Frontage = Linear feet of street connected to property.
# Is it possible that "null" means that the street is not connected to the property at all, or could it be MCAR?
#
# Filter to check the following variables when lot_frontage is null:
# - Street (Nominal): Type of road access to property
#        Grvl	Gravel
#        Pave	Paved
# - Lot Config (Nominal): Lot configuration
#        Inside	Inside lot
#        Corner	Corner lot
#        CulDSac	Cul-de-sac
#        FR2	Frontage on 2 sides of property
#        FR3	Frontage on 3 sides of property
# If the two variables are non-null when lot_frontage is null, it will be wrong to assign 0 or "none" to lot_frontage as the house obviously is exposed to the street. But if both street and lot_config are null when lot_frontage is null, then it really is zero.

# %%
# Filter data
train.loc[train.lot_frontage.isnull(), ["street", "lot_config", "lot_shape", "lot_area"]]
# Out:
#      street lot_config lot_shape  lot_area
# 0      Pave    CulDSac       IR1     13517
# 7      Pave     Inside       IR1     12160
# 8      Pave     Inside       Reg     15783
# 23     Pave     Inside       IR1      7980
# 27     Pave     Inside       IR1     11700
# 31     Pave     Corner       IR1     11435
# 42     Pave     Corner       IR1      9101
# 50     Pave     Inside       Reg      2998
# 59     Pave     Corner       IR2     15038
# 62     Pave     Inside       IR1     20062
# 71     Pave     Inside       IR2     23730
# 75     Grvl     Inside       IR1      6291
# 76     Pave     Inside       Reg     17529
# 90     Pave     Inside       IR1     11104
# 91     Pave     Corner       IR3     15295
# 94     Pave     Corner       IR1     14112
# 106    Pave        FR2       Reg      2651
# 108    Pave    CulDSac       IR1     39384
# 111    Pave     Inside       IR1     12342
# 114    Pave     Corner       Reg      9000
# 117    Pave     Inside       IR1      4765
# 118    Pave     Corner       Reg     10532
# 122    Pave     Inside       IR1      9945
# 125    Pave    CulDSac       IR1     24572
# 141    Pave     Inside       IR1      8658
# 142    Pave     Corner       IR1      6897
# 148    Pave     Inside       Reg      8826
# 150    Pave     Inside       Reg     10710
# 160    Pave     Inside       Reg     25339
# 161    Pave     Inside       IR1      8883
# 166    Pave     Inside       Reg      5700
# 169    Pave    CulDSac       IR1      7400
# 176    Pave     Inside       IR1      7861
# 177    Pave     Inside       Reg     11616
# 192    Pave     Inside       IR1      9819
# 200    Pave     Inside       Reg      1533
# 208    Pave     Inside       Reg      3196
# 210    Pave    CulDSac       IR1     11241
# 221    Pave     Inside       IR1     10659
# 223    Pave     Inside       Reg     13500
# 226    Pave        FR2       Reg      4500
# 236    Pave     Corner       Reg     22002
# 250    Pave    CulDSac       IR1     11929
# 253    Pave     Inside       Reg     11423
# 262    Pave     Corner       IR1     17979
# 268    Pave     Inside       Reg      7050
# 284    Pave     Inside       IR1      9125
# 285    Pave     Corner       Reg     11075
# 290    Pave     Corner       IR1     11836
# 293    Pave     Inside       Reg      4426
# 295    Pave     Inside       Reg      2887
# 309    Pave    CulDSac       IR1      5814
# 310    Pave    CulDSac       IR2     14860
# 311    Pave    CulDSac       IR1     14803
# 320    Pave     Inside       IR1     12358
# 327    Pave     Inside       IR1      4928
# 328    Pave     Inside       IR1     12692
# 333    Pave     Inside       IR1     11888
# 334    Pave     Inside       Reg      7082
# 335    Pave        FR2       IR1      8755
# 337    Pave     Inside       Reg     32463
# 339    Pave     Inside       Reg      3696
# 346    Pave    CulDSac       IR1     10246
# 370    Pave     Inside       IR1     12700
# 372    Pave     Inside       IR1      8638
# 375    Pave     Inside       Reg     12774
# 389    Pave     Inside       IR1     12328
# 403    Pave     Inside       Reg      2117
# 411    Pave     Corner       IR1      7917
# 416    Pave     Inside       IR1      8885
# 428    Pave    CulDSac       IR2     15896
# 430    Pave        FR2       IR2      5105
# 435    Pave     Corner       IR1      9556
# 444    Pave    CulDSac       IR1      7472
# 446    Pave     Inside       IR1     11717
# 452    Pave    CulDSac       IR1      8014
# 453    Pave     Inside       IR1     12250
# 454    Pave        FR2       IR1      2403
# 463    Pave     Inside       IR1      9763
# 469    Pave     Inside       IR1     11800
# 471    Pave    CulDSac       IR2    159000
# 482    Pave     Inside       IR1     12205
# 490    Pave     Corner       IR1      9636
# 500    Pave     Inside       Reg      9130
# 504    Pave     Inside       Reg      3621
# 511    Pave     Inside       Reg      3940
# 514    Pave    CulDSac       IR1     11515
# 515    Pave     Corner       IR1     13837
# 531    Pave     Inside       IR1      6853
# 541    Pave     Inside       IR1      4538
# 543    Pave    CulDSac       IR1     13346
# 545    Pave    CulDSac       IR1     15387
# 547    Pave     Inside       Reg      6240
# 549    Pave     Inside       Reg      8900
# 553    Pave     Inside       IR1      8050
# 555    Pave     Inside       IR1      7920
# 557    Pave     Inside       IR1      7162
# 560    Pave     Inside       Reg     11250
# 561    Pave    CulDSac       IR1     14375
# 570    Pave    CulDSac       IR1     12150
# 572    Pave     Inside       IR1     22692
# 575    Pave     Inside       Reg      4435
# 576    Pave     Corner       Reg      5890
# 593    Pave    CulDSac       IR1     14585
# 595    Pave     Inside       IR1     13774
# 603    Pave     Inside       IR1      9240
# 626    Pave     Inside       Reg     11050
# 628    Pave     Corner       IR1      9610
# 639    Pave     Corner       IR1     15660
# 660    Pave     Inside       Reg      5100
# 661    Pave    CulDSac       IR1      9720
# 668    Pave     Inside       IR1      9205
# 671    Pave    CulDSac       IR1     14357
# 680    Pave    CulDSac       IR1     11000
# 681    Pave     Inside       IR1     10337
# 691    Pave     Inside       IR1      9019
# 694    Pave    CulDSac       IR2    115149
# 716    Pave    CulDSac       IR1      7703
# 727    Pave    CulDSac       IR1     13265
# 731    Pave     Corner       IR1      9303
# 732    Pave    CulDSac       IR1      8544
# 733    Pave     Corner       IR1     11425
# 737    Pave    CulDSac       IR1     15635
# 742    Pave     Inside       IR1      8098
# 745    Pave     Inside       IR1     57200
# 747    Pave    CulDSac       Reg     12384
# 748    Pave     Inside       IR1      9927
# 750    Pave     Inside       IR1      7915
# 757    Pave     Corner       IR1     10920
# 760    Pave    CulDSac       IR1      9947
# 764    Pave     Inside       IR1     10600
# 765    Pave     Inside       IR1     18890
# 767    Pave     Inside       Reg      7750
# 781    Pave        FR2       Reg     17199
# 811    Pave     Inside       IR1     10970
# 818    Pave     Inside       Reg     11354
# 827    Pave    CulDSac       IR1     13526
# 830    Pave     Inside       IR1      7830
# 835    Pave     Inside       IR1     12585
# 849    Pave     Inside       IR1     10456
# 850    Pave     Inside       IR1      8475
# 864    Pave     Inside       IR1      9930
# 871    Pave     Inside       IR1      7424
# 875    Pave     Inside       IR1     12929
# 876    Pave     Inside       IR1      9316
# 877    Pave     Corner       IR1     12122
# 913    Pave    CulDSac       IR1     32668
# 919    Pave     Inside       Reg      6615
# 921    Pave     Corner       Reg     11088
# 926    Pave        FR2       IR1     12735
# 927    Pave        FR2       Reg     11000
# 938    Pave     Inside       IR1      8121
# 941    Pave     Corner       IR3      9771
# 944    Pave     Corner       IR1     10448
# 950    Pave     Inside       Reg      2665
# 957    Pave     Inside       IR1      9156
# 966    Pave     Corner       IR1     15957
# 971    Pave    CulDSac       IR1     17082
# 980    Pave     Corner       Reg     21000
# 982    Pave     Inside       IR1      8750
# 1000   Pave     Inside       IR1     10708
# 1004   Pave     Inside       IR1      9572
# 1007   Pave     Inside       IR1     10899
# 1009   Pave    CulDSac       IR1     16647
# 1017   Pave     Inside       IR1      7500
# 1030   Pave     Inside       Reg      8063
# 1042   Pave     Inside       Reg     10320
# 1048   Pave     Inside       Reg     10200
# 1049   Pave    CulDSac       IR1      9555
# 1052   Pave    CulDSac       IR1     53227
# 1066   Pave     Inside       IR1     12760
# 1067   Pave    CulDSac       IR1      7655
# 1070   Pave    CulDSac       IR1      9505
# 1079   Pave     Inside       Reg      6240
# 1090   Pave     Inside       Reg     24090
# 1105   Pave     Inside       IR1      8076
# 1113   Pave     Inside       IR1      8010
# 1114   Pave     Inside       IR1     10050
# 1117   Pave     Inside       Reg     11400
# 1121   Pave     Inside       IR1      3612
# 1125   Pave     Inside       Reg      8544
# 1142   Pave     Inside       IR1     15676
# 1152   Pave    CulDSac       IR1     21579
# 1165   Pave    CulDSac       IR1     11120
# 1167   Pave     Inside       IR1     47280
# 1173   Pave     Inside       IR1     12285
# 1181   Pave     Inside       Reg     13650
# 1183   Pave     Corner       IR1      9450
# 1185   Pave     Inside       Reg      7153
# 1203   Pave    CulDSac       IR1     10147
# 1208   Pave     Corner       IR1      9981
# 1211   Pave     Inside       IR1      8239
# 1212   Pave     Corner       IR1      5700
# 1216   Pave     Inside       Reg      4224
# 1223   Pave     Inside       Reg      2938
# 1233   Pave     Inside       IR1     10825
# 1237   Pave     Inside       Reg     11838
# 1240   Pave     Inside       IR1      8396
# 1243   Pave     Corner       IR1     15498
# 1244   Pave     Corner       IR1     12891
# 1249   Pave    CulDSac       IR1     19690
# 1259   Pave     Inside       Reg     11050
# 1264   Pave     Inside       IR1     12046
# 1271   Pave     Inside       Reg     12728
# 1275   Pave     Inside       Reg      9375
# 1277   Pave     Inside       Reg     17140
# 1288   Pave     Inside       Reg      9790
# 1293   Pave     Corner       IR1     12511
# 1303   Pave     Inside       IR1     19522
# 1306   Pave     Corner       IR1     11950
# 1311   Pave     Inside       Reg      3196
# 1313   Pave     Corner       IR1      6820
# 1316   Pave     Inside       Reg      8000
# 1333   Pave     Inside       IR1     12099
# 1336   Pave     Inside       IR1     17600
# 1338   Pave    CulDSac       IR1      8685
# 1342   Pave     Inside       Reg     12568
# 1357   Pave    CulDSac       IR1      9373
# 1370   Pave     Corner       IR1      8926
# 1372   Pave     Inside       IR1     10020
# 1387   Pave    CulDSac       IR1     13680
# 1393   Pave     Inside       IR1      8963
# 1397   Pave     Corner       IR1     12227
# 1398   Pave     Inside       IR1      9248
# 1414   Pave    CulDSac       IR1      6563
# 1420   Pave     Corner       IR1     20693
# 1426   Pave     Inside       IR1      8068
# 1427   Pave     Inside       IR1      8917
# 1430   Pave     Inside       Reg      7500
# 1436   Pave     Inside       IR1      8010
# 1438   Pave     Corner       IR1      3136
# 1450   Pave    CulDSac       IR1      9531
# 1453   Pave     Corner       IR1      9991
# 1458   Pave     Corner       IR1     17541
# 1469   Pave     Inside       Reg      4435
# 1475   Pave    CulDSac       IR1      9308
# 1491   Pave     Inside       IR1     12493
# 1492   Pave    CulDSac       IR1     10368
# 1495   Pave     Inside       IR1      9819
# 1508   Pave     Corner       IR1      7425
# 1513   Pave     Corner       IR1      8978
# 1514   Pave     Inside       IR1      9079
# 1515   Pave     Inside       Reg      1700
# 1521   Pave    CulDSac       IR1      9638
# 1523   Pave     Inside       Reg     17597
# 1527   Pave     Inside       Reg      2117
# 1530   Pave     Inside       IR1     11553
# 1533   Pave     Inside       Reg      7500
# 1536   Pave    CulDSac       IR1      7176
# 1538   Pave     Corner       Reg     11235
# 1540   Pave     Corner       IR1     14541
# 1548   Pave     Inside       IR2     17871
# 1565   Pave     Inside       IR1      6718
# 1566   Pave     Inside       Reg     11855
# 1567   Pave     Corner       IR1     12394
# 1576   Pave     Corner       IR1     15611
# 1582   Pave     Corner       IR1     11029
# 1583   Pave        FR3       IR1     14311
# 1587   Pave     Inside       IR1     10603
# 1597   Pave     Inside       IR1      9535
# 1605   Pave     Inside       Reg      7939
# 1606   Pave     Inside       Reg      7750
# 1608   Pave     Inside       Reg      7750
# 1610   Pave     Inside       IR1     13607
# 1611   Pave     Inside       Reg      4435
# 1616   Pave    CulDSac       IR1     16269
# 1623   Pave     Inside       IR1     11027
# 1625   Pave     Inside       IR1     18275
# 1631   Pave     Inside       IR1      6173
# 1660   Pave     Inside       IR1      9216
# 1664   Pave     Inside       IR1     10364
# 1666   Pave     Corner       IR1     10530
# 1668   Pave     Inside       IR1      8880
# 1690   Pave     Inside       Reg     11885
# 1695   Pave     Inside       IR1     18450
# 1696   Pave    CulDSac       IR1     14778
# 1702   Pave     Corner       IR1     13142
# 1721   Pave     Corner       IR2     11454
# 1726   Pave     Inside       IR1     50102
# 1735   Pave     Inside       IR3     12155
# 1736   Pave     Corner       Reg      7446
# 1740   Pave     Corner       IR1      9830
# 1741   Pave     Inside       IR2      4403
# 1742   Pave     Inside       IR1      8174
# 1745   Pave     Inside       IR1      8795
# 1757   Pave     Inside       IR1      8789
# 1765   Pave     Corner       Reg      7758
# 1770   Pave    CulDSac       IR1     11200
# 1783   Pave     Inside       IR1      8020
# 1784   Pave     Inside       IR1     11341
# 1791   Pave     Corner       IR1      8145
# 1803   Pave     Corner       IR2     11000
# 1807   Pave     Corner       IR1     13215
# 1813   Pave     Inside       Reg      3072
# 1816   Pave     Inside       IR1     14364
# 1822   Pave     Corner       IR1      8970
# 1832   Pave    CulDSac       IR1     10762
# 1843   Pave     Corner       IR2     53107
# 1858   Pave    CulDSac       IR2     14781
# 1865   Pave     Inside       IR1     11677
# 1866   Pave        FR2       Reg     11000
# 1869   Pave     Corner       IR1     13495
# 1873   Pave     Inside       IR1      8530
# 1874   Pave     Inside       IR2     13041
# 1882   Pave     Inside       IR1      8740
# 1910   Pave     Inside       IR1     11792
# 1918   Pave     Corner       IR1     11275
# 1924   Pave     Inside       IR1     11692
# 1925   Pave     Corner       IR1     12546
# 1926   Pave     Corner       IR1     21695
# 1933   Pave     Corner       IR2     14762
# 1941   Pave     Inside       Reg      7851
# 1943   Pave     Inside       IR1      8398
# 1947   Pave     Inside       Reg     12800
# 1949   Pave     Corner       IR1     12224
# 1956   Pave     Inside       Reg     14115
# 1960   Pave        FR2       IR2     21533
# 1963   Pave     Inside       IR1     13250
# 1967   Pave    CulDSac       IR1      9839
# 1977   Pave     Inside       IR1     16545
# 1998   Pave        FR2       IR1     16635
# 2001   Pave    CulDSac       IR2     14171
# 2003   Pave     Inside       IR2     12968
# 2008   Pave     Corner       IR1     11500
# 2015   Pave    CulDSac       IR1      9928
# 2016   Pave     Inside       IR1      7791
# 2022   Pave     Inside       IR1     16381
# 2028   Pave    CulDSac       IR2     20781
# 2031   Pave    CulDSac       IR1     12537
# 2047   Pave     Inside       IR1     12342

# %% [markdown]
# Looks like null values are not zero values as all of them have road access and a number of them even have frontages on 2 or 3 sides of the property.
# I shall check if a regression imputation makes sense, as using mean/median/mode might skew the histogram too much. For example, a property with a large lot_area should have a larger lot_frontage, and I notice that there are zero missing values for lot_area, so that makes a good variable to create imputated values.

# %%
# Confirm lot_area has no missing values
train.lot_area.isnull().sum()
# Out:
# 0

# %%
# Plot of lot_frontage against lot_area
sns.lmplot(data = train, x = "lot_area", y = "lot_frontage");

# %% [markdown]
# An imputation using basic regression looks workable, outliers don't seem to affect the slope much.
# I shall create dummy variables for "neighborhood" to further account for differences in location (e.g. properties located closer to the city centre might have small lot frontages, all else equal).

# %%
# Set up imputation regression

# Pull in relevant variables
df = train[['lot_frontage', 'lot_area', 'neighborhood']]

# Create dummies for neighborhood variable
df = pd.get_dummies(df, drop_first = True)

y = df.loc[df.lot_frontage.notnull(), 'lot_frontage']
X = df.loc[df.lot_frontage.notnull(), :].drop(columns = {"lot_frontage"})

# Instantiate model
lr = LinearRegression()

# Fit model
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
# save indices of missing values
missing_idx = train.index[train.lot_frontage.isnull()]
missing_idx
# Out:
# Int64Index([   0,    7,    8,   23,   27,   31,   42,   50,   59,   62,
#             ...
#             1998, 2001, 2003, 2008, 2015, 2016, 2022, 2028, 2031, 2047],
#            dtype='int64', length=330)

# %%
# Impute missing values with the prediciton from the model
df['lot_frontage_imputed'] = [
    df.loc[
        i,'lot_frontage'
    ] if i not in missing_idx
    else lr.predict(
        pd.DataFrame(
            df.loc[i,~df.columns.isin(['lot_frontage',
                                       'lot_frontage_imputed'])]).T)[0]
    for i in range(df.shape[0])
]

# %% [markdown]
# An imputation using basic regression looks workable, outliers don't seem to affect the slope much.
# I shall create dummy variables for "neighborhood" to further account for differences in location (e.g. properties located closer to the city centre might have small lot frontages, all else equal).

# %%
# Reasonability check against mean and median imputation
mean_frontage = df.lot_frontage.mean()
median_frontage = df.lot_frontage.median()

df['frontage_mean_imputed'] = train.lot_frontage.fillna(mean_frontage)
df['frontage_median_imputed'] = train.lot_frontage.fillna(median_frontage)

df[['lot_frontage','lot_area', 'lot_frontage_imputed',
    'frontage_mean_imputed', 'frontage_median_imputed']
  ].describe()
# Out:
#        lot_frontage       lot_area  lot_frontage_imputed  \
# count   1721.000000    2051.000000           2051.000000
# mean      69.055200   10065.208191             70.226908
# std       23.260653    6742.488909             24.234477
# min       21.000000    1300.000000             21.000000
# 25%       58.000000    7500.000000             60.000000
# 50%       68.000000    9430.000000             70.000000
# 75%       80.000000   11513.500000             80.000000
# max      313.000000  159000.000000            400.666844
#
#        frontage_mean_imputed  frontage_median_imputed
# count            2051.000000              2051.000000
# mean               69.055200                68.885422
# std                21.306357                21.309886
# min                21.000000                21.000000
# 25%                60.000000                60.000000
# 50%                69.055200                68.000000
# 75%                78.000000                78.000000
# max               313.000000               313.000000

# %% [markdown]
# Looks like regression imputation is better than mean/median imputation, as the latter two seem to distort the histogram and artificially compress the variance of lot_frontage. Will go with regression imputation.

# %%
# Merge imputed values to train data set
train = pd.merge(
    left = train,
    right = df['lot_frontage_imputed'],
    left_index = True,
    right_index = True
)

# %%
# Check merger is done correctly
train.loc[:, ['lot_frontage', 'lot_frontage_imputed']].sample(25)
# Out:
#       lot_frontage  lot_frontage_imputed
# 741           74.0             74.000000
# 1511          55.0             55.000000
# 1981          35.0             35.000000
# 1747          85.0             85.000000
# 192            NaN             72.374325
# 1900          78.0             78.000000
# 923           57.0             57.000000
# 884           82.0             82.000000
# 1136          60.0             60.000000
# 1740           NaN             75.665761
# 616          123.0            123.000000
# 158           60.0             60.000000
# 1456          81.0             81.000000
# 92            70.0             70.000000
# 1467         102.0            102.000000
# 1234          50.0             50.000000
# 1720          50.0             50.000000
# 2020          58.0             58.000000
# 111            NaN             81.285322
# 1193          69.0             69.000000
# 1141          75.0             75.000000
# 1138          24.0             24.000000
# 1608           NaN             64.009358
# 913            NaN            119.380004
# 608           90.0             90.000000

# %% [markdown]
# Looks like

# %%
# Check 1
train.lot_frontage_imputed.isnull().sum()
# Out:
# 0

# %%
# Check 2
fig, axes = plt.subplots(ncols=2, nrows=1, figsize=(15,5))
fig.suptitle('Plot of Sales Price against Lot Frontage and Imputed Lot Frontage')

sns.regplot(data = train, x = "lot_frontage", y = "saleprice", ax = axes[0])
sns.regplot(data = train, x = "lot_frontage_imputed", y = "saleprice", ax = axes[1]);

# %% [markdown]
# Conversion from string to number looks correct: higher fireplace_qu values seem to indicate higher sale prices
#
# Update tracking table for converted ordinal variables
#
# | Variable | Original Categories (in order of increasing quality) | Replacement Numbers (higher is better)|
# |----------|-------------------------------------------|---------------------------------------|
# | pool_qc | NA -> Fa -> TA -> Gd -> Ex | 0-1-2-3-4 |
# | fireplace_qu | NA -> Po -> Fa -> TA -> Gd -> Ex | 0-1-2-3-4-5 |
